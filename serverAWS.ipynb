# %%
# Cell 1: Import Dependencies & Setup
import json
import logging
import sqlite3
import time
import psutil
import requests
import secrets
from http.server import BaseHTTPRequestHandler, HTTPServer

# --- Configuration ---
PORT = 5001
GO_SERVICE_URL = "http://127.0.0.1:8080/verify"
DB_FILE = "commitments.db"

# --- Logging Setup ---
logging.basicConfig(
    level=logging.INFO, 
    format='%(asctime)s - %(levelname)s - %(message)s'
)

print(f"--- Server Configured on Port {PORT} ---")
print(f"--- Upstream ZKP Verifier: {GO_SERVICE_URL} ---")
# Out:
# --- Server Configured on Port 5001 ---
# --- Upstream ZKP Verifier: http://127.0.0.1:8080/verify ---

# %%
# Cell 2: Database Management Functions

def get_db_connection():
    """Creates a connection to the database with WAL mode enabled."""
    conn = sqlite3.connect(DB_FILE)
    conn.execute('PRAGMA journal_mode=WAL;') # Write-Ahead Logging for concurrency
    return conn

def init_db():
    """Initializes the database schema if it doesn't exist."""
    conn = get_db_connection()
    cursor = conn.cursor()
    # Updated to include salt storage for Argon2id compatibility
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS commitments (
            id INTEGER PRIMARY KEY,
            username TEXT NOT NULL UNIQUE,
            commitment TEXT NOT NULL,
            salt TEXT NOT NULL
        )
    ''')
    conn.commit()
    conn.close()
    logging.info("Database initialized with salt storage.")

def reset_db():
    """Truncates the commitments table. Used for testing."""
    try:
        conn = get_db_connection()
        conn.execute("DELETE FROM commitments")
        conn.commit()
        conn.close()
        logging.info("Database reset (all rows cleared).")
        return True
    except sqlite3.Error as e:
        logging.error(f"Database Error during reset: {e}")
        return False

def save_commitment(username, commitment, salt):
    """Stores a new User -> Commitment + Salt mapping."""
    conn = get_db_connection()
    cursor = conn.cursor()
    try:
        cursor.execute(
            'INSERT INTO commitments (username, commitment, salt) VALUES (?, ?, ?)', 
            (username, commitment, salt)
        )
        conn.commit()
    except sqlite3.IntegrityError:
        return False # User already exists
    finally:
        conn.close()
    return True

def get_stored_commitment(username):
    """Retrieves the commitment string for a specific user."""
    conn = get_db_connection()
    cursor = conn.cursor()
    cursor.execute('SELECT commitment FROM commitments WHERE username = ?', (username,))
    row = cursor.fetchone()
    conn.close()
    return row[0] if row else None

def get_user_data(username):
    """Retrieves both commitment and salt for a specific user."""
    conn = get_db_connection()
    cursor = conn.cursor()
    cursor.execute('SELECT commitment, salt FROM commitments WHERE username = ?', (username,))
    row = cursor.fetchone()
    conn.close()
    if row:
        return {"commitment": row[0], "salt": row[1]}
    return None

# Initialize immediately on cell run
init_db()
# Out:
# 2026-02-21 14:47:37,664 - INFO - Database initialized with salt storage.

# %%
# Cell 3: Helper Functions (Metrics & ZKP)

def log_metrics(start_time, url):
    """Logs request duration and system resource usage."""
    elapsed = time.time() - start_time
    cpu = psutil.cpu_percent(interval=None)
    ram = psutil.virtual_memory().percent
    logging.info(f"[{url}] took {elapsed:.4f}s | Sys: CPU {cpu}% RAM {ram}%")

def verify_proof_upstream(proof, public_witness):
    """
    Forwards the Proof and Public Witness to the Go Service.
    The Go Service performs the actual BN254 Elliptic Curve pairing check.
    """
    payload = {
        "proof": proof,
        "public_witness": public_witness
    }
    
    try:
        # We set a strict timeout to ensure responsiveness
        response = requests.post(GO_SERVICE_URL, json=payload, timeout=5)
        
        if response.status_code == 200:
            result = response.json()
            is_valid = result.get('valid', False)
            logging.info(f"Go Verification Result: {is_valid}")
            return is_valid
        else:
            logging.error(f"Go Service Error: {response.status_code} - {response.text}")
            return False
    except Exception as e:
        logging.error(f"Failed to contact Go Service: {e}")
        return False

print("--- Logic Layer Ready ---")
# Out:
# --- Logic Layer Ready ---

# %%
# Cell 4: HTTP Request Handler & Server Loop (Secure Witness Construction)

active_challenges = set()

class RequestHandler(BaseHTTPRequestHandler):
    
    def _send_json(self, code, data):
        self.send_response(code)
        self.send_header('Content-type', 'application/json')
        self.end_headers()
        self.wfile.write(json.dumps(data).encode())

    def do_GET(self):
        if self.path == '/challenge':
            # Generate a fresh 64-bit nonce
            nonce = str(secrets.randbits(64))
            active_challenges.add(nonce)
            self._send_json(200, {'challenge': nonce})
        else:
            self.send_error(404)

    def do_POST(self):
        try:
            content_length = int(self.headers.get('Content-Length', 0))
            body = self.rfile.read(content_length).decode('utf-8')
            data = json.loads(body) if body else {}

            if self.path == '/enroll':
                self.handle_enroll(data)
            elif self.path == '/verifyCommitment':
                self.handle_verify(data)
            elif self.path == '/reset':
                self.handle_reset()
            else:
                self.send_error(404)
        except Exception as e:
            logging.error(f"Server Error: {e}")
            self._send_json(500, {"error": str(e)})

    def handle_reset(self):
        active_challenges.clear()
        if reset_db():
            self._send_json(200, {"message": "Reset success"})
        else:
            self._send_json(500, {"error": "Reset failed"})

    def handle_enroll(self, data):
        username = data.get('username')
        # [NEW] We now expect the raw commitment string, not the witness blob
        commitment = data.get('commitment') 
        salt = data.get('salt') # [FIXED] Extract salt from request

        if not username or not commitment or not salt:
            return self._send_json(400, {"error": "Missing fields"})

        # [FIXED] Pass salt to save_commitment
        if save_commitment(username, commitment, salt):
            logging.info(f"User enrolled: {username}")
            self._send_json(201, {"message": "Enrollment successful"})
        else:
            self._send_json(409, {"error": "User already exists"})

    def handle_verify(self, data):
        username = data.get('username')
        proof = data.get('proof')
        challenge_response = data.get('challenge')

        if not username or not proof or not challenge_response:
            return self._send_json(400, {"error": "Missing fields"})

        # 1. Nonce Check
        if challenge_response not in active_challenges:
            logging.warning(f"Replay/Expire for {username}")
            return self._send_json(403, {"error": "Invalid/Expired Challenge"})
        
        active_challenges.remove(challenge_response)

        # 2. Retrieve Stored Commitment (Identity Source of Truth)
        stored_commitment = get_stored_commitment(username)
        if not stored_commitment:
            return self._send_json(403, {"error": "User not found"})

        # 3. Secure Verification Check
        # Prevents attempts to bypass binding with null or default nonces
        if not challenge_response or challenge_response == "0":
             return self._send_json(403, {"error": "Illegal Challenge Value"})

        payload = {
            "proof": proof,
            "commitment": stored_commitment,
            "challenge": challenge_response
        }
        
        try:
            response = requests.post(GO_SERVICE_URL, json=payload, timeout=5)
            if response.status_code == 200 and response.json().get('valid'):
                logging.info(f"Auth Success: {username}")
                self._send_json(200, {"message": "Login Successful"})
            else:
                logging.warning(f"Auth Failed: {username}")
                self._send_json(403, {"error": "Invalid ZKP (Proof does not match User/Challenge)"})
        except Exception as e:
            logging.error(f"Go Service Fail: {e}")
            self._send_json(500, {"error": "Internal Verifier Error"})

def run():
    server_address = ('0.0.0.0', PORT)
    try:
        httpd = HTTPServer(server_address, RequestHandler)
        print(f'>>> Authentication Server running on http://0.0.0.:{PORT} <<<')
        httpd.serve_forever()
    except OSError as e:
        print(f"Server Start Error: {e}")

if __name__ == '__main__':
    run()
# Out:
# >>> Authentication Server running on http://127.0.0.1:5001 <<<
# 2026-02-21 14:51:15,539 - INFO - Database reset (all rows cleared).
# 127.0.0.1 - - [21/Feb/2026 14:51:15] "POST /reset HTTP/1.1" 200 -
# 2026-02-21 14:51:15,962 - INFO - User enrolled: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:15] "POST /enroll HTTP/1.1" 201 -
# 2026-02-21 14:51:16,440 - INFO - User enrolled: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:16] "POST /enroll HTTP/1.1" 201 -
# 2026-02-21 14:51:16,851 - INFO - User enrolled: user_02
# 127.0.0.1 - - [21/Feb/2026 14:51:16] "POST /enroll HTTP/1.1" 201 -
# 2026-02-21 14:51:17,417 - INFO - User enrolled: user_03
# 127.0.0.1 - - [21/Feb/2026 14:51:17] "POST /enroll HTTP/1.1" 201 -
# 2026-02-21 14:51:17,850 - INFO - User enrolled: user_04
# 127.0.0.1 - - [21/Feb/2026 14:51:17] "POST /enroll HTTP/1.1" 201 -
# 2026-02-21 14:51:18,239 - INFO - User enrolled: user_05
# 127.0.0.1 - - [21/Feb/2026 14:51:18] "POST /enroll HTTP/1.1" 201 -
# 2026-02-21 14:51:18,684 - INFO - User enrolled: user_06
# 127.0.0.1 - - [21/Feb/2026 14:51:18] "POST /enroll HTTP/1.1" 201 -
# 2026-02-21 14:51:19,072 - INFO - User enrolled: user_07
# 127.0.0.1 - - [21/Feb/2026 14:51:19] "POST /enroll HTTP/1.1" 201 -
# 2026-02-21 14:51:19,472 - INFO - User enrolled: user_08
# 127.0.0.1 - - [21/Feb/2026 14:51:19] "POST /enroll HTTP/1.1" 201 -
# 2026-02-21 14:51:20,206 - INFO - User enrolled: user_09
# 127.0.0.1 - - [21/Feb/2026 14:51:20] "POST /enroll HTTP/1.1" 201 -
# 127.0.0.1 - - [21/Feb/2026 14:51:20] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:20,491 - INFO - Auth Success: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:20] "POST /verifyCommitment HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Feb/2026 14:51:20] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:20,764 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:20] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:20] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:21,020 - INFO - Auth Success: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:21] "POST /verifyCommitment HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Feb/2026 14:51:21] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:21,315 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:21] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:21] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:21,577 - INFO - Auth Success: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:21] "POST /verifyCommitment HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Feb/2026 14:51:21] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:21,854 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:21] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:21] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:22,156 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:22] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:22] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:22,496 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:22] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:22] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:22,791 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:22] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:22] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:23,094 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:23] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:23] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:23,371 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:23] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:23] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:23,635 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:23] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:23] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:23,932 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:23] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:23] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:24,200 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:24] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:24] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:24,494 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:24] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:24] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:24,775 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:24] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:24] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:25,066 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:25] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:25] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:25,308 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:25] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:25] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:25,567 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:25] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:25] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:25,850 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:25] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:25] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:26,138 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:26] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:26] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:26,413 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:26] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:26] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:26,670 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:26] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:26] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:26,960 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:26] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:26] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:27,224 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:27] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:27] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:27,488 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:27] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:27] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:27,776 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:27] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:27] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:28,057 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:28] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:28] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:28,324 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:28] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:28] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:28,578 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:28] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:28] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:28,871 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:28] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:28] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:29,156 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:29] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:29] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:29,425 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:29] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:29] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:29,715 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:29] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:29] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:29,980 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:29] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:29] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:30,248 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:30] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:30] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:30,513 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:30] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:30] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:30,809 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:30] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:30] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:31,064 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:31] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:31] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:31,323 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:31] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:31] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:31,575 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:31] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:31] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:31,846 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:31] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:31] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:32,120 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:32] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:32] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:32,417 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:32] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:32] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:32,688 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:32] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:32] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:32,944 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:32] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:32] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:33,195 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:33] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:33] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:33,465 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:33] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:33] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:33,777 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:33] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:33] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:34,058 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:34] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:34] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:34,311 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:34] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:34] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:34,587 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:34] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:34] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:34,865 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:34] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:34] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:35,133 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:35] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:35] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:35,427 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:35] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:35] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:35,711 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:35] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:35] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:35,991 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:35] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:36] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:36,227 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:36] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:36] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:36,498 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:36] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:36] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:36,804 - WARNING - Auth Failed: user_00
# 127.0.0.1 - - [21/Feb/2026 14:51:36] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:36] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:37,084 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:37] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:37] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:37,443 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:37] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:37] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:37,711 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:37] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:37] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:37,991 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:37] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:38] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:38,259 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:38] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:38] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:38,573 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:38] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:38] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:38,841 - INFO - Auth Success: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:38] "POST /verifyCommitment HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Feb/2026 14:51:38] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:39,150 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:39] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:39] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:39,433 - INFO - Auth Success: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:39] "POST /verifyCommitment HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Feb/2026 14:51:39] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:39,688 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:39] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:39] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:39,982 - INFO - Auth Success: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:39] "POST /verifyCommitment HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Feb/2026 14:51:39] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:40,265 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:40] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:40] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:40,544 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:40] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:40] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:40,810 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:40] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:40] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:41,089 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:41] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:41] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:41,374 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:41] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:41] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:41,653 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:41] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:41] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:41,934 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:41] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:41] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:42,259 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:42] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:42] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:42,541 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:42] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:42] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:42,823 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:42] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:42] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:43,104 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:43] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:43] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:43,388 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:43] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:43] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:43,669 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:43] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:43] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:43,935 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:43] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:43] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:44,177 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:44] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:44] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:44,432 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:44] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:44] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:44,698 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:44] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:44] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:45,011 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:45] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:45] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:45,271 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:45] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:45] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:45,559 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:45] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:45] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:45,854 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:45] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:45] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:46,136 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:46] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:46] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:46,415 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:46] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:46] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:46,681 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:46] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:46] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:46,961 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:46] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:46] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:47,258 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:47] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:47] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:47,516 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:47] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:47] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:47,765 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:47] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:47] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:48,031 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:48] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:48] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:48,295 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:48] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:48] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:48,565 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:48] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:48] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:48,847 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:48] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:48] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:49,128 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:49] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:49] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:49,408 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:49] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:49] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:49,688 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:49] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:49] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:49,985 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:49] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:49] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:50,267 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:50] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:50] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:50,550 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:50] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:50] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:50,807 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:50] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:50] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:51,056 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:51] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:51] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:51,310 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:51] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:51] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:51,547 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:51] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:51] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:51,844 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:51] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:51] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:52,124 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:52] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:52] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:52,406 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:52] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:52] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:52,702 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:52] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:52] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:52,966 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:52] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:52] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:53,263 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:53] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:53] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:53,520 - WARNING - Auth Failed: user_01
# 127.0.0.1 - - [21/Feb/2026 14:51:53] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:53] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:53,780 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:51:53] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:53] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:54,075 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:51:54] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:54] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:54,358 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:51:54] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:54] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:54,639 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:51:54] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:54] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:54,899 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:51:54] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:54] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:55,158 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:51:55] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:55] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:55,451 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:51:55] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:55] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:55,742 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:51:55] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:55] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:56,029 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:51:56] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:56] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:56,278 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:51:56] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:56] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:56,539 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:51:56] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:56] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:56,824 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:51:56] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:56] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:57,090 - INFO - Auth Success: user_02
# 127.0.0.1 - - [21/Feb/2026 14:51:57] "POST /verifyCommitment HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Feb/2026 14:51:57] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:57,358 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:51:57] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:57] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:57,636 - INFO - Auth Success: user_02
# 127.0.0.1 - - [21/Feb/2026 14:51:57] "POST /verifyCommitment HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Feb/2026 14:51:57] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:57,901 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:51:57] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:57] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:58,170 - INFO - Auth Success: user_02
# 127.0.0.1 - - [21/Feb/2026 14:51:58] "POST /verifyCommitment HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Feb/2026 14:51:58] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:58,484 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:51:58] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:58] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:58,766 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:51:58] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:58] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:59,092 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:51:59] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:59] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:59,385 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:51:59] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:59] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:59,669 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:51:59] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:59] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:51:59,965 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:51:59] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:51:59] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:00,245 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:00] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:00] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:00,559 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:00] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:00] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:00,829 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:00] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:00] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:01,091 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:01] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:01] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:01,358 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:01] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:01] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:01,643 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:01] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:01] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:01,937 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:01] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:01] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:02,222 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:02] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:02] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:02,482 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:02] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:02] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:02,736 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:02] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:02] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:03,030 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:03] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:03] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:03,313 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:03] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:03] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:03,613 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:03] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:03] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:03,889 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:03] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:03] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:04,189 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:04] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:04] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:04,461 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:04] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:04] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:04,721 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:04] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:04] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:04,988 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:04] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:05] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:05,269 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:05] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:05] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:05,552 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:05] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:05] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:05,833 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:05] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:05] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:06,087 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:06] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:06] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:06,397 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:06] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:06] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:06,679 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:06] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:06] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:07,054 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:07] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:07] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:07,371 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:07] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:07] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:07,665 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:07] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:07] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:07,936 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:07] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:07] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:08,245 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:08] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:08] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:08,528 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:08] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:08] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:08,811 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:08] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:08] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:09,121 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:09] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:09] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:09,385 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:09] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:09] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:09,654 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:09] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:09] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:09,935 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:09] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:09] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:10,230 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:10] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:10] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:10,496 - WARNING - Auth Failed: user_02
# 127.0.0.1 - - [21/Feb/2026 14:52:10] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:10] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:10,778 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:10] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:10] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:11,048 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:11] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:11] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:11,342 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:11] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:11] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:11,620 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:11] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:11] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:11,888 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:11] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:11] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:12,169 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:12] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:12] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:12,435 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:12] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:12] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:12,734 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:12] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:12] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:13,013 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:13] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:13] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:13,292 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:13] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:13] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:13,562 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:13] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:13] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:13,857 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:13] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:13] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:14,150 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:14] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:14] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:14,433 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:14] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:14] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:14,704 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:14] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:14] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:15,010 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:15] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:15] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:15,273 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:15] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:15] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:15,542 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:15] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:15] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:15,842 - INFO - Auth Success: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:15] "POST /verifyCommitment HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Feb/2026 14:52:15] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:16,123 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:16] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:16] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:16,391 - INFO - Auth Success: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:16] "POST /verifyCommitment HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Feb/2026 14:52:16] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:16,686 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:16] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:16] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:16,951 - INFO - Auth Success: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:16] "POST /verifyCommitment HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Feb/2026 14:52:16] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:17,235 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:17] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:17] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:17,519 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:17] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:17] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:17,813 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:17] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:17] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:18,085 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:18] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:18] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:18,357 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:18] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:18] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:18,602 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:18] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:18] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:18,853 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:18] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:18] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:19,131 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:19] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:19] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:19,412 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:19] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:19] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:19,755 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:19] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:19] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:20,063 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:20] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:20] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:20,343 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:20] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:20] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:20,624 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:20] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:20] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:20,919 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:20] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:20] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:21,206 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:21] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:21] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:21,483 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:21] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:21] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:21,748 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:21] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:21] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:22,030 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:22] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:22] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:22,292 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:22] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:22] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:22,562 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:22] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:22] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:22,816 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:22] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:22] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:23,086 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:23] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:23] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:23,367 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:23] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:23] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:23,625 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:23] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:23] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:23,868 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:23] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:23] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:52:24,200 - WARNING - Auth Failed: user_03
# 127.0.0.1 - - [21/Feb/2026 14:52:24] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:52:24] "GET /challenge HTTP/1.1" 200 -
# ...
# 127.0.0.1 - - [21/Feb/2026 14:53:50] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:53:51,327 - WARNING - Auth Failed: user_08
# 127.0.0.1 - - [21/Feb/2026 14:53:51] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:53:51] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:53:51,659 - WARNING - Auth Failed: user_08
# 127.0.0.1 - - [21/Feb/2026 14:53:51] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:53:51] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:53:51,970 - WARNING - Auth Failed: user_08
# 127.0.0.1 - - [21/Feb/2026 14:53:51] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:53:51] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:53:52,280 - WARNING - Auth Failed: user_08
# 127.0.0.1 - - [21/Feb/2026 14:53:52] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:53:52] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:53:52,518 - WARNING - Auth Failed: user_08
# 127.0.0.1 - - [21/Feb/2026 14:53:52] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:53:52] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:53:52,808 - INFO - Auth Success: user_08
# 127.0.0.1 - - [21/Feb/2026 14:53:52] "POST /verifyCommitment HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Feb/2026 14:53:52] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:53:53,101 - WARNING - Auth Failed: user_08
# 127.0.0.1 - - [21/Feb/2026 14:53:53] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:53:53] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:53:53,417 - INFO - Auth Success: user_08
# 127.0.0.1 - - [21/Feb/2026 14:53:53] "POST /verifyCommitment HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Feb/2026 14:53:53] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:53:53,675 - WARNING - Auth Failed: user_08
# 127.0.0.1 - - [21/Feb/2026 14:53:53] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:53:53] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:53:54,003 - INFO - Auth Success: user_08
# 127.0.0.1 - - [21/Feb/2026 14:53:54] "POST /verifyCommitment HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Feb/2026 14:53:54] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:53:54,282 - WARNING - Auth Failed: user_08
# 127.0.0.1 - - [21/Feb/2026 14:53:54] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:53:54] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:53:54,523 - WARNING - Auth Failed: user_08
# 127.0.0.1 - - [21/Feb/2026 14:53:54] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:53:54] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:53:54,788 - WARNING - Auth Failed: user_08
# 127.0.0.1 - - [21/Feb/2026 14:53:54] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:53:54] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:53:55,131 - WARNING - Auth Failed: user_08
# 127.0.0.1 - - [21/Feb/2026 14:53:55] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:53:55] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:53:55,475 - WARNING - Auth Failed: user_08
# 127.0.0.1 - - [21/Feb/2026 14:53:55] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:53:55] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:53:55,787 - WARNING - Auth Failed: user_08
# 127.0.0.1 - - [21/Feb/2026 14:53:55] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:53:55] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:53:56,092 - WARNING - Auth Failed: user_08
# 127.0.0.1 - - [21/Feb/2026 14:53:56] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:53:56] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:53:56,427 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:53:56] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:53:56] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:53:56,698 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:53:56] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:53:56] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:53:57,017 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:53:57] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:53:57] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:53:57,327 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:53:57] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:53:57] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:53:57,575 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:53:57] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:53:57] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:53:57,886 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:53:57] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:53:57] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:53:58,213 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:53:58] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:53:58] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:53:58,490 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:53:58] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:53:58] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:53:58,739 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:53:58] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:53:58] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:53:58,990 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:53:58] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:53:58] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:53:59,273 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:53:59] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:53:59] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:53:59,573 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:53:59] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:53:59] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:53:59,865 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:53:59] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:53:59] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:00,145 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:00] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:00] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:00,412 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:00] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:00] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:00,706 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:00] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:00] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:00,991 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:00] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:01] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:01,287 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:01] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:01] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:01,640 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:01] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:01] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:01,941 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:01] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:01] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:02,296 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:02] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:02] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:02,575 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:02] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:02] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:02,812 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:02] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:02] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:03,107 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:03] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:03] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:03,439 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:03] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:03] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:03,716 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:03] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:03] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:04,027 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:04] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:04] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:04,340 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:04] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:04] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:04,578 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:04] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:04] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:04,853 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:04] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:04] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:05,156 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:05] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:05] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:05,497 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:05] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:05] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:05,781 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:05] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:05] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:06,094 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:06] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:06] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:06,420 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:06] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:06] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:06,686 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:06] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:06] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:06,975 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:06] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:06] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:07,201 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:07] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:07] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:07,436 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:07] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:07] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:07,761 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:07] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:07] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:08,037 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:08] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:08] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:08,302 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:08] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:08] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:08,583 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:08] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:08] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:08,869 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:08] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:08] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:09,132 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:09] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:09] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:09,361 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:09] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:09] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:09,600 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:09] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:09] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:09,867 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:09] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:09] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:10,112 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:10] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:10] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:10,385 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:10] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:10] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:10,698 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:10] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:10] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:10,977 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:10] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:11] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:11,319 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:11] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:11] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:11,615 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:11] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:11] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:11,944 - INFO - Auth Success: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:11] "POST /verifyCommitment HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Feb/2026 14:54:11] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:12,219 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:12] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:12] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:12,550 - INFO - Auth Success: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:12] "POST /verifyCommitment HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Feb/2026 14:54:12] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:12,845 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:12] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:12] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:13,157 - INFO - Auth Success: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:13] "POST /verifyCommitment HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Feb/2026 14:54:13] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:13,419 - WARNING - Auth Failed: user_09
# 127.0.0.1 - - [21/Feb/2026 14:54:13] "POST /verifyCommitment HTTP/1.1" 403 -
# 127.0.0.1 - - [21/Feb/2026 14:54:13] "GET /challenge HTTP/1.1" 200 -
# 2026-02-21 14:54:13,685 - INFO - Auth Success: user_00
# 127.0.0.1 - - [21/Feb/2026 14:54:13] "POST /verifyCommitment HTTP/1.1" 200 -
# 2026-02-21 14:54:13,688 - WARNING - Replay/Expire for user_00
# 127.0.0.1 - - [21/Feb/2026 14:54:13] "POST /verifyCommitment HTTP/1.1" 403 -
